# %%
#Winning the Trifecta: A look at Time, Place, Wager, and Risk Off-Track and Beyond…


#I decided to use the Illinois Racing Board datasets that dealt with the monthly wagers at Illinois racetracks, 
#off-track-betting parlors, and advanced deposit wagers for the years 2011 and 2012. The data is broken-down into 
#the year, the month the wagers were placed, the locations they were placed at, and the total amount of the wagers. 
#For my data visualizations, there are dropdown menus where the user can select which location they want to view, 
#which then interacts with the scatter plot to show the corresponding month and wager amount associated with the location. 
#To help make the data visualizations run faster, I only chose a random sample of 100. 

#Here, I am importing the data to work with it a try and plot some of the points with a visualization.
import pandas as pd
import bqplot
import numpy as np
import traitlets
import ipywidgets
from ipywidgets import widgets, interact
# %matplotlib inline
#I found this import command from github at https://github.com/konstantint/matplotlib-venn/issues/33:
from matplotlib import pyplot as plt

# %%
#Importing the data.

otb_data=pd.read_csv("otb_wagers_il_2011.csv")
otb_data
# Out:
#        _1       _2       arlington_at_chicago_weed_street_otb    january
# 0    2011  3329857     ARLINGTON AT CHICAGO, WEED STREET -OTB    JANUARY
# 1    2011  1467892                ARLINGTON AT HODGKINS - OTB    JANUARY
# 2    2011  1421410                ARLINGTON AT WAUKEGAN - OTB    JANUARY
# 3    2011   306946  ARLINGTON AT WAUKEGAN SUNDANCE SALOON-OTB    JANUARY
# 4    2011   942414            ARLINGTON PARK RACECOURSE - IT.    JANUARY
# 5    2011  3428912            ARLINGTON PARK RACECOURSE, LLC.    JANUARY
# 6    2011   315065                BALMORAL AT CHAMPAIGN - OTB    JANUARY
# 7    2011  1914378                BALMORAL AT CRESTWOOD - OTB    JANUARY
# 8    2011   349083                   BALMORAL AT NORMAL - OTB    JANUARY
# 9    2011   817015                 BALMORAL RACING CLUB, INC.    JANUARY
# 10   2011   660649           BALMORAL RACING CLUB, INC. - IT.    JANUARY
# 11   2011   367739                   FAIRMOUNT AT ALTON - OTB    JANUARY
# 12   2011   892269                  FAIRMOUNT AT SAUGET - OTB    JANUARY
# 13   2011   446668             FAIRMOUNT AT SPRINGFIELD - OTB    JANUARY
# 14   2011  1751790                 FAIRMOUNT PARK, INC. - IT.    JANUARY
# 15   2011   565256                  HAWTHORNE AT AURORA - OTB    JANUARY
# 16   2011   670965           HAWTHORNE AT BUFFALO GROVE - OTB    JANUARY
# 17   2011  2002340        HAWTHORNE AT CHICAGO, CORLISS - OTB    JANUARY
# 18   2011   972315                  HAWTHORNE AT JOLIET - OTB    JANUARY
# 19   2011  1053574                  HAWTHORNE AT MOKENA - OTB    JANUARY
# 20   2011    90100               HAWTHORNE AT YORKVILLE - OTB    JANUARY
# 21   2011  3031934          HAWTHORNE RACE COURSE, INC. - IT.    JANUARY
# 22   2011   676201         MAYWOOD AT ELK GROVE VILLAGE - OTB    JANUARY
# 23   2011  2010393                     MAYWOOD AT NILES - OTB    JANUARY
# 24   2011   499585              MAYWOOD AT NORTH AURORA - OTB    JANUARY
# 25   2011  2239436                  MAYWOOD AT OAKBROOK - OTB    JANUARY
# 26   2011  2594229     MAYWOOD PARK TROTTING ASSOCIATION -IT.    JANUARY
# 27   2011   624548    MAYWOOD PARK TROTTING ASSOCIATION, INC.    JANUARY
# 28   2011   492975                QUAD CITY AT LOCKPORT - OTB    JANUARY
# 29   2011   622443                 QUAD CITY AT MCHENRY - OTB    JANUARY
# ..    ...      ...                                        ...        ...
# 447  2011   778195           BALMORAL RACING CLUB, INC. - IT.  DECEMBER
# 448  2011   336830                   FAIRMOUNT AT ALTON - OTB  DECEMBER
# 449  2011   726803                  FAIRMOUNT AT SAUGET - OTB  DECEMBER
# 450  2011   485946             FAIRMOUNT AT SPRINGFIELD - OTB  DECEMBER
# 451  2011  2242372                 FAIRMOUNT PARK, INC. - IT.  DECEMBER
# 452  2011   624919                  HAWTHORNE AT AURORA - OTB  DECEMBER
# 453  2011   469729           HAWTHORNE AT BUFFALO GROVE - OTB  DECEMBER
# 454  2011  2063858        HAWTHORNE AT CHICAGO, CORLISS - OTB  DECEMBER
# 455  2011   990980                  HAWTHORNE AT JOLIET - OTB  DECEMBER
# 456  2011   938531                  HAWTHORNE AT MOKENA - OTB  DECEMBER
# 457  2011   166926               HAWTHORNE AT YORKVILLE - OTB  DECEMBER
# 458  2011  4535444                HAWTHORNE RACE COURSE, INC.  DECEMBER
# 459  2011   820159          HAWTHORNE RACE COURSE, INC. - IT.  DECEMBER
# 460  2011   623275         MAYWOOD AT ELK GROVE VILLAGE - OTB  DECEMBER
# 461  2011  2156471                     MAYWOOD AT NILES - OTB  DECEMBER
# 462  2011   488326              MAYWOOD AT NORTH AURORA - OTB  DECEMBER
# 463  2011  1936095                  MAYWOOD AT OAKBROOK - OTB  DECEMBER
# 464  2011  2589967     MAYWOOD PARK TROTTING ASSOCIATION -IT.  DECEMBER
# 465  2011   828556    MAYWOOD PARK TROTTING ASSOCIATION, INC.  DECEMBER
# 466  2011   528565                QUAD CITY AT LOCKPORT - OTB  DECEMBER
# 467  2011   773253                 QUAD CITY AT MCHENRY - OTB  DECEMBER
# 468  2011   885242                QUAD CITY AT ROCKFORD - OTB  DECEMBER
# 469  2011   389311            QUAD CITY AT SOUTH BELOIT - OTB  DECEMBER
# 470  2011   593666             QUAD CITY AT SOUTH ELGIN - OTB  DECEMBER
# 471  2011   620044                QUAD CITY DOWNS, INC. - IT.  DECEMBER
# 472  2011  1562800                                 YOUBET ADW  DECEMBER
# 473  2011  3227611                            TWIN SPIRES ADW  DECEMBER
# 474  2011  2682619                                    TVG ADW  DECEMBER
# 475  2011    92048                               BETZOTIC ADW  DECEMBER
# 476  2011   859113                              XPRESSBET ADW  DECEMBER
#
# [477 rows x 4 columns]

# %%
len(otb_data)
# Out:
# 477

# %%
#I'm going to pull out the data information in the "Wagers" column and the "Months" column and plot these figures with a visualization.

stats_2=otb_data.groupby('arlington_at_chicago_weed_street_otb')['_2'].describe()
stats_2
# Out:
#                                            count          mean           std  \
# arlington_at_chicago_weed_street_otb
# HAWTHORNE AT CHICAGO, CORLISS - OTB         2321200.00   2516166.0
# HAWTHORNE AT JOLIET - OTB                   1116261.75   1434385.0
# HAWTHORNE AT MOKENA - OTB                   1055883.25   1353862.0
# HAWTHORNE AT YORKVILLE - OTB                 190150.00    227055.0
# HAWTHORNE RACE COURSE, INC.                 4829749.00   5191028.0
# HAWTHORNE RACE COURSE, INC. - IT.           3127999.00   3829125.0
# MAYWOOD AT ELK GROVE VILLAGE - OTB           676565.75    754916.0
# MAYWOOD AT NILES - OTB                      2270536.00   2707054.0
# MAYWOOD AT NORTH AURORA - OTB                535070.00    636353.0
# MAYWOOD AT OAKBROOK - OTB                   2434010.00   3256557.0
# MAYWOOD PARK TROTTING ASSOCIATION -IT.      2874501.00   3487335.0
# MAYWOOD PARK TROTTING ASSOCIATION, INC.      842194.50    912676.0
# QUAD CITY AT LOCKPORT - OTB                  536888.25    613962.0
# QUAD CITY AT MCHENRY - OTB                   798309.50    856006.0
# QUAD CITY AT ROCKFORD - OTB                  849557.25   1102055.0
# QUAD CITY AT SOUTH BELOIT - OTB              446800.00    581019.0
# QUAD CITY AT SOUTH ELGIN - OTB               690618.50    785094.0
# QUAD CITY DOWNS, INC. - IT.                  774001.75    962977.0
# TVG ADW                                     3165145.75   3722651.0
# TWIN SPIRES ADW                             3666589.25   4625604.0
# XPRESSBET ADW                                902278.50   1060572.0
# YOUBET ADW                                  1867277.75   2804049.0

# %%
#Random sample of 100.

nsamples=100
downSampleMask=np.random.randint(0,len(otb_data)-1,nsamples)
downSampleMask
# Out:
# array([  2, 294, 235, 351, 208, 413, 397, 105, 453, 220, 233, 401,  78,
#        318, 173, 234, 230, 418, 212, 415, 351, 167,  42, 202, 153,  78,
#        285, 345, 252,  90,  26,  23, 122, 346, 145,  76, 304, 351, 241,
#        365, 413, 376, 414, 139, 426, 417, 199, 250,  58,  61, 464, 258,
#        258, 473, 296, 182,  62, 167, 218, 162, 405, 388, 175, 402, 301,
#         20, 474, 448, 106, 123,  13,  63, 437,  77, 365,  52, 473, 336,
#        263, 316, 265, 458, 470,   1, 348,   5, 103, 180,  86, 211, 288,
#        427, 258, 301, 397, 222, 337, 454, 335, 219])

# %%
downSampleMask=np.random.choice(range(len(otb_data)-1),
                               nsamples, replace=False)

# %%
otb_dataDS=otb_data.loc[downSampleMask]
len(otb_dataDS)
# Out:
# 100

# %%
otb_dataDS
# Out:
#        _1        _2       arlington_at_chicago_weed_street_otb     january
# 445  2011    316360                   BALMORAL AT NORMAL - OTB   DECEMBER
# 269  2011    767684                QUAD CITY DOWNS, INC. - IT.       JULY
# 141  2011    549557              MAYWOOD AT NORTH AURORA - OTB      APRIL
# 83   2011   2639582                BALMORAL AT CRESTWOOD - OTB       MARCH
# 2    2011   1421410                ARLINGTON AT WAUKEGAN - OTB     JANUARY
# 319  2011   3212251     ARLINGTON AT CHICAGO, WEED STREET -OTB  SEPTEMBER
# 393  2011    550538                QUAD CITY DOWNS, INC. - IT.    OCTOBER
# 222  2011   2819615     MAYWOOD PARK TROTTING ASSOCIATION -IT.       JUNE
# 300  2011    227055               HAWTHORNE AT YORKVILLE - OTB     AUGUST
# 165  2011    937495           BALMORAL RACING CLUB, INC. - IT.        MAY
# 189  2011    754311             QUAD CITY AT SOUTH ELGIN - OTB        MAY
# 131  2011    629555                  HAWTHORNE AT AURORA - OTB      APRIL
# 129  2011   1017164                       FAIRMOUNT PARK, INC.      APRIL
# 118  2011   1820185                ARLINGTON AT WAUKEGAN - OTB      APRIL
# 457  2011    166926               HAWTHORNE AT YORKVILLE - OTB   DECEMBER
# 150  2011    828923                QUAD CITY DOWNS, INC. - IT.      APRIL
# 328  2011    312280                   BALMORAL AT NORMAL - OTB  SEPTEMBER
# 212  2011    600551           HAWTHORNE AT BUFFALO GROVE - OTB       JUNE
# 246  2011    387617                   FAIRMOUNT AT ALTON - OTB       JULY
# 439  2011   1497122                ARLINGTON AT HODGKINS - OTB   DECEMBER
# 356  2011   3189367                            TWIN SPIRES ADW  SEPTEMBER
# 398  2011    837334                              XPRESSBET ADW    OCTOBER
#
# [100 rows x 4 columns]

# %%
#I'm now defining the scales for my scatter plot.

x_sc= bqplot.OrdinalScale()
y_sc= bqplot.OrdinalScale()
c_sc= bqplot.ColorScale()

#I'm now defining the axes.
x_ax=bqplot.Axis(scale=x_sc, label='Month')
y_ax=bqplot.Axis(scale=y_sc, label='Wager', orientation='vertical')
c_ax=bqplot.ColorAxis(scale=c_sc, color='blue',label='$(Thousands)', orientation='vertical', side='right')

#Selecting the marks
scatters=bqplot.Scatter(x=otb_dataDS['january'], y=otb_dataDS['_2'],
                       color=np.log10(otb_dataDS['_2']),
                       scales={'x':x_sc, 'y':y_sc, 'color':c_sc})

fig=bqplot.Figure(marks=[scatters], axes=[x_ax, y_ax, c_ax], title='2011 OTB Wagers based off of Location')
fig.layout.min_width='960px'
fig.layout.min_height='640px'

#This part of my code including the ipywidget and interact function is sourced from Professor Naiman's notes she sent to me:
@ipywidgets.interact(options=otb_data['arlington_at_chicago_weed_street_otb'].unique())


#This function was sourced from Professor Naiman:
def get_locations_value(options):
    mask=otb_data['arlington_at_chicago_weed_street_otb']==options
    #print(otb_data['january'])
    
    scatters.x=otb_dataDS['january'][mask]
    scatters.y=otb_dataDS['_2'][mask]
fig
# Out:
# interactive(children=(Dropdown(description='options', options=('ARLINGTON AT CHICAGO, WEED STREET -OTB', 'ARLI…
# Figure(axes=[Axis(label='Month', scale=OrdinalScale()), Axis(label='Wager', orientation='vertical', scale=Ordi…

# %%
#2nd Visualization for Final Project!

# %%
#Here, I am importing the data to work with it a try and plot some of the points with a visualization. All of the code
#here I have referenced from various weeks of class notes.

import pandas as pd
import bqplot
import numpy as np
import traitlets
import ipywidgets
from ipywidgets import widgets, interact
# %matplotlib inline
#I found this import command from github at https://github.com/konstantint/matplotlib-venn/issues/33:
from matplotlib import pyplot as plt

# %%
#Importing the data.

otb_data=pd.read_csv("/Users/elizabethjenkins/otb_data_2012.csv")
otb_data
# Out:
#         handle live_or_simulcast                                 location  \
# 0     268798.3              LIVE    ARLINGTON AT CHICAGO, JOE'S BAR - OTB
# 1    2529237.4              SIMS    ARLINGTON AT CHICAGO, JOE'S BAR - OTB
# 2     110511.1              LIVE              ARLINGTON AT HODGKINS - OTB
# 3    1257378.1              SIMS              ARLINGTON AT HODGKINS - OTB
# 4      70069.3              LIVE            ARLINGTON AT VILLA PARK - OTB
# 5     762329.2              SIMS            ARLINGTON AT VILLA PARK - OTB
# 6      83177.1              LIVE              ARLINGTON AT WAUKEGAN - OTB
# 7    1406680.8              SIMS              ARLINGTON AT WAUKEGAN - OTB
# 8     156604.7              LIVE          ARLINGTON PARK RACECOURSE - IT.
# 9     617239.5              SIMS          ARLINGTON PARK RACECOURSE - IT.
# 10   2876443.5              SIMS          ARLINGTON PARK RACECOURSE, LLC.
# 11     27840.0              LIVE              BALMORAL AT CHAMPAIGN - OTB
# 12    281339.0              SIMS              BALMORAL AT CHAMPAIGN - OTB
# 13    250390.4              LIVE              BALMORAL AT CRESTWOOD - OTB
# 14   1770765.5              SIMS              BALMORAL AT CRESTWOOD - OTB
# 15     18672.5              LIVE                 BALMORAL AT NORMAL - OTB
# 16    265211.2              SIMS                 BALMORAL AT NORMAL - OTB
# 17    517400.4              LIVE               BALMORAL RACING CLUB, INC.
# 18    229693.2              SIMS               BALMORAL RACING CLUB, INC.
# 19     27351.8              LIVE         BALMORAL RACING CLUB, INC. - IT.
# 20    623264.5              SIMS         BALMORAL RACING CLUB, INC. - IT.
# 21     15568.8              LIVE                 FAIRMOUNT AT ALTON - OTB
# 22    305344.1              SIMS                 FAIRMOUNT AT ALTON - OTB
# 23     48186.2              LIVE                FAIRMOUNT AT SAUGET - OTB
# 24    650175.8              SIMS                FAIRMOUNT AT SAUGET - OTB
# 25     21145.1              LIVE           FAIRMOUNT AT SPRINGFIELD - OTB
# 26    353469.7              SIMS           FAIRMOUNT AT SPRINGFIELD - OTB
# 27     76529.9              LIVE               FAIRMOUNT PARK, INC. - IT.
# 28   1594621.5              SIMS               FAIRMOUNT PARK, INC. - IT.
# 29     48617.8              LIVE                HAWTHORNE AT AURORA - OTB
# ..         ...               ...                                      ...
# 906    48082.4              LIVE         MAYWOOD AT HOFFMAN ESTATES - OTB
# 907   237727.3              SIMS         MAYWOOD AT HOFFMAN ESTATES - OTB
# 908    78449.2              LIVE                MAYWOOD AT LOCKPORT - OTB
# 909   285230.2              SIMS                MAYWOOD AT LOCKPORT - OTB
# 910   369328.7              LIVE                   MAYWOOD AT NILES - OTB
# 911  1630907.4              SIMS                   MAYWOOD AT NILES - OTB
# 912    74803.0              LIVE            MAYWOOD AT NORTH AURORA - OTB
# 913   334203.6              SIMS            MAYWOOD AT NORTH AURORA - OTB
# 914   429276.6              LIVE                MAYWOOD AT OAKBROOK - OTB
# 915  1772522.3              SIMS                MAYWOOD AT OAKBROOK - OTB
# 916   465079.1              LIVE  MAYWOOD PARK TROTTING ASSOCIATION - IT.
# 917  1881066.3              SIMS  MAYWOOD PARK TROTTING ASSOCIATION - IT.
# 918   347470.6              LIVE  MAYWOOD PARK TROTTING ASSOCIATION, INC.
# 919   301682.0              SIMS  MAYWOOD PARK TROTTING ASSOCIATION, INC.
# 920    96758.3              LIVE               QUAD CITY AT MCHENRY - OTB
# 921   510512.0              SIMS               QUAD CITY AT MCHENRY - OTB
# 922   157661.7              LIVE              QUAD CITY AT ROCKFORD - OTB
# 923   708999.7              SIMS              QUAD CITY AT ROCKFORD - OTB
# 924    87182.9              LIVE           QUAD CITY AT SOUTH ELGIN - OTB
# 925   387248.1              SIMS           QUAD CITY AT SOUTH ELGIN - OTB
# 926   110787.5              LIVE              QUAD CITY DOWNS, INC. - IT.
# 927   493276.3              SIMS              QUAD CITY DOWNS, INC. - IT.
# 928   686226.0              LIVE                       TWIN SPIRES/YOUBET
# 929  3882871.4              SIMS                       TWIN SPIRES/YOUBET
# 930   373294.7              LIVE                                      TVG
# 931  2985639.0              SIMS                                      TVG
# 932    69648.7              LIVE                                 BETZOTIC
# 933    80964.9              SIMS                                 BETZOTIC
# 934   180826.7              LIVE                                XPRESSBET
# 935   957635.4              SIMS                                XPRESSBET
#
#         month  year
# 0     January  2012
# 1     January  2012
# 2     January  2012
# 3     January  2012
# 4     January  2012
# 5     January  2012
# 6     January  2012
# 7     January  2012
# 8     January  2012
# 9     January  2012
# 10    January  2012
# 11    January  2012
# 12    January  2012
# 13    January  2012
# 14    January  2012
# 15    January  2012
# 16    January  2012
# 17    January  2012
# 18    January  2012
# 19    January  2012
# 20    January  2012
# 21    January  2012
# 22    January  2012
# 23    January  2012
# 24    January  2012
# 25    January  2012
# 26    January  2012
# 27    January  2012
# 28    January  2012
# 29    January  2012
# ..        ...   ...
# 906  December  2012
# 907  December  2012
# 908  December  2012
# 909  December  2012
# 910  December  2012
# 911  December  2012
# 912  December  2012
# 913  December  2012
# 914  December  2012
# 915  December  2012
# 916  December  2012
# 917  December  2012
# 918  December  2012
# 919  December  2012
# 920  December  2012
# 921  December  2012
# 922  December  2012
# 923  December  2012
# 924  December  2012
# 925  December  2012
# 926  December  2012
# 927  December  2012
# 928  December  2012
# 929  December  2012
# 930  December  2012
# 931  December  2012
# 932  December  2012
# 933  December  2012
# 934  December  2012
# 935  December  2012
#
# [936 rows x 5 columns]

# %%
len(otb_data)
# Out:
# 936

# %%
#Random sample of 100.

nsamples=100
downSampleMask=np.random.randint(0,len(otb_data)-1,nsamples)
downSampleMask
# Out:
# array([ 64, 933, 479, 393,   1, 464, 334, 571, 637, 425, 173, 487, 365,
#        819, 776, 360, 524, 844, 172, 228, 249, 463, 654, 567, 563, 113,
#        299, 157, 399, 895, 437, 771, 452, 760, 647, 361,  10, 813, 826,
#        658, 110, 518, 142, 874, 814, 830, 384, 163, 772, 126, 332, 764,
#         23, 891, 539, 748, 158,  75,  82, 720, 509, 648, 904, 306, 282,
#        530, 197, 185,  66, 646, 289, 652, 824, 622, 668, 162, 182, 766,
#        913, 501, 530, 353, 811, 915, 400, 153,  18, 192,  39, 492, 805,
#        605, 132, 540, 915, 571, 212, 283, 799, 709])

# %%
downSampleMask=np.random.choice(range(len(otb_data)-1),
                               nsamples, replace=False)

# %%
otb_dataDS=otb_data.loc[downSampleMask]
len(otb_dataDS)
# Out:
# 100

# %%
otb_dataDS
# Out:
#         handle live_or_simulcast                                 location  \
# 299   450693.5              LIVE                                      TVG
# 752    76515.7              LIVE            MAYWOOD AT NORTH AURORA - OTB
# 124   284808.5              LIVE                MAYWOOD AT OAKBROOK - OTB
# 258   288553.9              SIMS         HAWTHORNE AT BUFFALO GROVE - OTB
# 730   211695.5              LIVE               FAIRMOUNT PARK, INC. - IT.
# 775    72010.7              SIMS                                 BETZOTIC
# 572   163863.2              LIVE                FAIRMOUNT AT SAUGET - OTB
# 53    227286.9              LIVE  MAYWOOD PARK TROTTING ASSOCIATION, INC.
# 249   648625.0              SIMS                FAIRMOUNT AT SAUGET - OTB
# 263   232172.2              LIVE                HAWTHORNE AT JOLIET - OTB
# 116   212478.9              LIVE        HAWTHORNE RACE COURSE, INC. - IT.
# 814   183108.8              LIVE                HAWTHORNE AT JOLIET - OTB
# 619   464672.4              LIVE                                      TVG
# 79    112252.7              LIVE            ARLINGTON AT VILLA PARK - OTB
# 764   121992.7              LIVE              QUAD CITY AT ROCKFORD - OTB
# 55     27131.1              LIVE              QUAD CITY AT LOCKPORT - OTB
# 432   135512.6              LIVE       MAYWOOD AT ELK GROVE VILLAGE - OTB
# 438   465896.6              LIVE                MAYWOOD AT OAKBROOK - OTB
# 9     617239.5              SIMS          ARLINGTON PARK RACECOURSE - IT.
# 95    666443.2              SIMS         BALMORAL RACING CLUB, INC. - IT.
# 216   638359.5              LIVE                       TWIN SPIRES/YOUBET
# 666   186245.9              LIVE                HAWTHORNE AT MOKENA - OTB
# 478    58878.4              LIVE              BALMORAL AT CHAMPAIGN - OTB
# 502   566745.3              SIMS      HAWTHORNE AT GLENDALE HEIGHTS - OTB
# 42   2684163.5              SIMS        HAWTHORNE RACE COURSE, INC. - IT.
# 579   170335.8              LIVE                HAWTHORNE AT AURORA - OTB
# 914   429276.6              LIVE                MAYWOOD AT OAKBROOK - OTB
# 92    653116.7              LIVE               BALMORAL RACING CLUB, INC.
# 783   467529.7              SIMS          ARLINGTON AT ORLAND HILLS - OTB
# 109  1772662.9              SIMS      HAWTHORNE AT CHICAGO, CORLISS - OTB
# ..         ...               ...                                      ...
# 614   474581.6              SIMS           QUAD CITY AT SOUTH ELGIN - OTB
# 811  1392833.4              SIMS      HAWTHORNE AT CHICAGO, CORLISS - OTB
# 344   223158.3              LIVE                HAWTHORNE AT JOLIET - OTB
# 251   342753.9              SIMS           FAIRMOUNT AT SPRINGFIELD - OTB
# 209   663462.6              SIMS              QUAD CITY AT ROCKFORD - OTB
#Note: "Handle" is another term for "Wager". - Source: https://m.vegas.com/gaming/gaming-tips/betting-glossary/

# %%
#I'm now defining the scales for my scatter plot.

x_sc= bqplot.OrdinalScale()
y_sc= bqplot.OrdinalScale()
c_sc= bqplot.ColorScale()

#I'm now defining the axes.
x_ax=bqplot.Axis(scale=x_sc, label='Month')
y_ax=bqplot.Axis(scale=y_sc, label='Wager', orientation='vertical')
c_ax=bqplot.ColorAxis(scale=c_sc, label='Log', orientation='vertical', side='right')

#Selecting the marks.
scatters=bqplot.Scatter(x=otb_dataDS['month'], y=otb_dataDS['handle'],
                       color=np.log10(otb_dataDS['handle']),
                       scales={'x':x_sc, 'y':y_sc, 'color':c_sc})
#Plotting the figure.
fig=bqplot.Figure(marks=[scatters], axes=[x_ax, y_ax, c_ax], title='2012 OTB Wagers based off of Location')

fig.layout.min_width='960px'
fig.layout.min_height='640px'
#fig

#This part of my code including the ipywidget and interact function is sourced from Professor Naiman's notes she sent to me:
@ipywidgets.interact(options=otb_data['location'].unique())

#This function was sourced from Professor Naiman:
def get_locations_value(options):
    mask=otb_data['location']==options
    scatters.x=otb_dataDS['month'][mask]
    scatters.y=otb_dataDS['handle'][mask]
fig
# Out:
# interactive(children=(Dropdown(description='options', options=("ARLINGTON AT CHICAGO, JOE'S BAR - OTB", 'ARLIN…
# Figure(axes=[Axis(label='Month', scale=OrdinalScale()), Axis(label='Wager', orientation='vertical', scale=Ordi…

# %%
#The two visualizations dealing with OTB Wagers in Illinois during 2011 and 2012 were created by me. 
#I wanted to show the differences and similarities of each year between the amount of wagers, 
#the locations the wagers were made, and the months the wagers were made. I wanted to have something users could 
#interact with and compare extremely similar data. Also, these datasets originated from the same site 
#(Illinois.data.gov) which gives the users a base of similarity amongst how the data was compiled. 
#The third and fourth visualizations are from a blog that illustrates the dangers of horse racing. 
#I wanted to include these data visualizations, not only because they include data from some of the locations 
#that were in the two datasets I used to create my visualizations, but to bring light to the physical toll horses 
#go through during races. 

#For the two data visualizations I created, each scatter plot has 100 random samples of data, 
#each point measuring the amount of wagers, or handles, made during each particular month. 
#The dropdown menu on each of these visualizations includes all of the different locations. By selecting a location from the 
#dropdown, the user can see where on the scatter plot that data is located. By sampling a smaller amount of data, 
#the user has less of a chance feeling overwhelmed by the amount of information in the dataset. The other two 
#visualizations are stagnant visualizations, a bar graph and a type of heat map. Although the map is far more 
#visually appealing, I wanted to also include the bar graph so users can see the information and have a more detailed 
#understanding on what data was being rendered onto the map. 

#Sources: 
#Datasets:
#https://data.illinois.gov/dataset/549irb_2011_monthly_amounts_wagered_at_illinois_racetracks_otb_parlors_and_advance_deposit_wagering

#https://data.illinois.gov/dataset/540illinois_racing_board_2012_monthly_amounts_wagered_at_illinois_racetracks_otb_parlors_and_advance

#Horse Racing Deaths Visualizations:
#https://heatherclemenceau.files.wordpress.com/2015/06/horse-racing-deaths-visual-analysis.jpg
 
#https://heatherclemenceau.files.wordpress.com/2015/06/horse-racing-deaths-2014.jpg
